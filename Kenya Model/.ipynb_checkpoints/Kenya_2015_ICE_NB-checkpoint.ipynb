# %%
import calliope
import Graphs as gg

# %%
try:
    calliope.set_log_level('INFO')
except:
    calliope.set_log_verbosity('INFO')
model = calliope.Model('model.yaml')
model.run()
# Out:
# [2020-04-23 13:41:46] INFO     Model: initialising
# [2020-04-23 13:41:46] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\calliope\core\preprocess\model_run.py:227: FutureWarning:
#
# There will be no default cost class for the objective function in v0.7.0 (currently "monetary" with a weight of 1). Explicitly specify the cost class(es) you would like to use under `run.objective_options.cost_class`. E.g. `{"monetary": 1}` to replicate the current default.
#
#
# [2020-04-23 13:41:46] WARNING  Warning: Possible issues found during model processing:
#  * `monetary` interest rate of zero for technology supply_biomass, setting depreciation rate as 1/lifetime.
#
# [2020-04-23 13:41:47] INFO     `BiogasStorage` at `NBOR` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2020-04-23 13:41:47] INFO     Model: preprocessing stage 1 (model_run)
# [2020-04-23 13:41:47] INFO     NumExpr defaulting to 4 threads.
# [2020-04-23 13:41:47] INFO     Model: preprocessing stage 2 (model_data)
# [2020-04-23 13:41:48] INFO     Model: preprocessing complete
# [2020-04-23 13:41:48] INFO     Backend: starting model run
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lifetime) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lifetime) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:51] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# ...
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs_conversion) to be 'Any',
#     you can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs_conversion)
# to be 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs_conversion) to be 'Any',
#     you can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs_conversion)
# to be 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs_conversion) to be 'Any',
#     you can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs_conversion)
# to be 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs_conversion) to be 'Any',
#     you can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs_conversion)
# to be 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (max_demand_timesteps) to be 'Any', you
#     can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (max_demand_timesteps) to be
# 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (max_demand_timesteps) to be 'Any', you
#     can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (max_demand_timesteps) to be
# 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (max_demand_timesteps) to be 'Any', you
#     can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-04-23 13:41:52] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (max_demand_timesteps) to be
# 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# [2020-04-23 13:41:52] INFO     constraints are loaded in the following order: ['capacity', 'costs', 'dispatch', 'energy_balance', 'network', 'policy', 'conversion', 'conversion_plus', 'group', 'export', 'milp']
# [2020-04-23 13:41:54] INFO     Backend: model generated. Time since start of model run: 0:00:05.259952
# [2020-04-23 13:41:54] INFO     Backend: sending model to solver
# [2020-04-23 13:41:55] DEBUG    GLPSOL: GLPK LP/MIP Solver, v4.62
# [2020-04-23 13:41:55] DEBUG    Parameter(s) specified in the command line:
# [2020-04-23 13:41:55] DEBUG    --write C:\Users\Amin\AppData\Local\Temp\tmp4pi0mnf0.glpk.raw --wglp C:\Users\Amin\AppData\Local\Temp\tmpuhjhynyq.glpk.glp
# [2020-04-23 13:41:55] DEBUG    --cpxlp C:\Users\Amin\AppData\Local\Temp\tmpc9bqcd1v.pyomo.lp
# [2020-04-23 13:41:55] DEBUG    Reading problem data from 'C:\Users\Amin\AppData\Local\Temp\tmpc9bqcd1v.pyomo.lp'...
# [2020-04-23 13:41:55] DEBUG    14163 rows, 9205 columns, 32858 non-zeros
# [2020-04-23 13:41:55] DEBUG    84641 lines were read
# [2020-04-23 13:41:55] DEBUG    Writing problem data to 'C:\Users\Amin\AppData\Local\Temp\tmpuhjhynyq.glpk.glp'...
# [2020-04-23 13:41:55] DEBUG    69506 lines were written
# [2020-04-23 13:41:55] DEBUG    GLPK Simplex Optimizer, v4.62
# [2020-04-23 13:41:55] DEBUG    14163 rows, 9205 columns, 32858 non-zeros
# [2020-04-23 13:41:55] DEBUG    Preprocessing...
# [2020-04-23 13:41:55] DEBUG    7760 rows, 6526 columns, 19884 non-zeros
# [2020-04-23 13:41:55] DEBUG    Scaling...
# [2020-04-23 13:41:55] DEBUG    A: min|aij| =  5.000e-01  max|aij| =  1.000e+00  ratio =  2.000e+00
# [2020-04-23 13:41:55] DEBUG    Problem data seem to be well scaled
# [2020-04-23 13:41:55] DEBUG    Constructing initial basis...
# [2020-04-23 13:41:55] DEBUG    Size of triangular part is 7743
# [2020-04-23 13:41:55] DEBUG    0: obj =   1.054062479e+07 inf =   2.473e+07 (96)
# [2020-04-23 13:41:56] DEBUG    264: obj =   8.401507299e+06 inf =   0.000e+00 (0)
# [2020-04-23 13:41:56] DEBUG    *   500: obj =   7.799646170e+06 inf =   0.000e+00 (427) 1
# [2020-04-23 13:41:56] DEBUG    *  1000: obj =   4.873383904e+06 inf =   0.000e+00 (30) 3
# [2020-04-23 13:41:56] DEBUG    *  1034: obj =   4.873378877e+06 inf =   1.179e-09 (0)
# [2020-04-23 13:41:56] DEBUG    OPTIMAL LP SOLUTION FOUND
# [2020-04-23 13:41:56] DEBUG    Time used:   0.4 secs
# [2020-04-23 13:41:56] DEBUG    Memory used: 13.0 Mb (13594697 bytes)
# [2020-04-23 13:41:56] DEBUG    Writing basic solution to 'C:\Users\Amin\AppData\Local\Temp\tmp4pi0mnf0.glpk.raw'...
# [2020-04-23 13:41:56] DEBUG    23377 lines were written
# [2020-04-23 13:41:56] INFO     Backend: solver finished running. Time since start of model run: 0:00:07.819165
# [2020-04-23 13:41:56] INFO     Backend: loaded results
# [2020-04-23 13:41:56] INFO     Backend: generated solution array. Time since start of model run: 0:00:07.936848
# [2020-04-23 13:41:56] INFO     Postprocessing: started
# [2020-04-23 13:41:57] INFO     Postprocessing: zero threshold of 1e-20 not required
# [2020-04-23 13:41:57] INFO     Postprocessing: ended. Time since start of model run: 0:00:08.489890

# %%
#my_pie,pie_pps,pie_cols = gg.Dispatch_sys(model,'bio_coffee_pp',pie_values='value')
a = gg.Dispatch_reg(model,sp_tech=False,sp_reg=False,weekly=False,pie_values='share')
# Out:
# [2020-04-23 13:41:58] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning:
#
# Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#
#
# [2020-04-23 13:41:59] WARNING  C:\Users\Amin\Documents\GitHub\My Kenya\Kenya Model\Graphs.py:333: MatplotlibDeprecationWarning:
#
# Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-414cd7018232> in <module>
#       1 #my_pie,pie_pps,pie_cols = gg.Dispatch_sys(model,'bio_coffee_pp',pie_values='value')
# ----> 2 a = gg.Dispatch_reg(model,sp_tech=False,sp_reg=False,weekly=False,pie_values='share')
#
# ~\Documents\GitHub\My Kenya\Kenya Model\Graphs.py in Dispatch_reg(model, sp_tech, sp_reg, weekly, pie_values)
#     144         for i in range (len(New_Nodes)):
#     145             for j in range (len(trans_list)):
# --> 146                 Exp_to[exp_list[i]] = Exp_to[exp_list[i]].values + model.get_formatted_array('carrier_con').loc[{'techs':[trans_loc[New_Nodes[i]].tolist()[j]],'carriers':Dem_tech.values[0,1],'locs':[region]}].sum('locs').sum('techs').to_pandas().T
#     147
#     148         for i in range(len(New_Nodes)):
#
# ~\Anaconda3\envs\calliope\lib\site-packages\pandas\core\series.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     810
#     811         # for binary ops, use our custom dunder methods
# --> 812         result = ops.maybe_dispatch_ufunc_to_dunder_op(
#     813             self, ufunc, method, *inputs, **kwargs
#     814         )
#
# ~\Anaconda3\envs\calliope\lib\site-packages\pandas\core\ops\__init__.py in maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#    1741         else:
#    1742             name = flipped.get(op_name, "__r{}__".format(op_name))
# -> 1743             return getattr(self, name, not_implemented)(inputs[0])
#    1744     else:
#    1745         return NotImplemented
#
# ~\Anaconda3\envs\calliope\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# ~\Anaconda3\envs\calliope\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     966
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#     970             result = masked_arith_op(x, y, op)
#
# ~\Anaconda3\envs\calliope\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     219     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#     223
#
# ~\Anaconda3\envs\calliope\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     125
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#     129     return result
#
# ~\Anaconda3\envs\calliope\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ~\Anaconda3\envs\calliope\lib\site-packages\pandas\core\ops\roperator.py in radd(left, right)
#       7
#       8 def radd(left, right):
# ----> 9     return right + left
#      10
#      11
#
# ValueError: operands could not be broadcast together with shapes (8,) (48,)

# %%
a

# %%
plt.figure(figsize=(15,10))
plt.pie(a.values,
        shadow=True, startangle=90,colors=c)
plt.legend(b,
          title="Power Plants",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
# Add a table at the bottom of the axes
the_table = plt.table(cellText=a.values.T,
                      colColours=c ,
                      rowLabels='%',
                      loc='bottom',
                     rowLoc ='center',
                     colLoc='center',
                     cellLoc='center')
#plt.subplots_adjust(left=0.0, bottom=0.0)
plt.show()

# %%
b

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.title('System Energy Mix',fontname="Times New Roman",fontweight="bold",fontsize=24)
plt.pie(my_pie.values,
        shadow=False, startangle=90,colors=pie_cols)


#Add a table at the bottom of the axes
the_table = plt.table(cellText=my_pie.values,
                      rowColours=pie_cols,
                      rowLabels= pie_pps,
                      colLabels = my_pie.columns,
                      loc='right',
                     rowLoc ='center',
                     colLoc='center',
                     cellLoc='center',bbox=(1.25,0.2,0.5,0.5)) 
the_table.auto_set_font_size(False)
the_table.set_fontsize(15)

#the_table[(2, 0)].get_text().set_fontsize(12)
#the_table[(2, 0)].get_text().set_color('red')
plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9)
#plt.savefig(r'Graphs\Pie_System_Result.svg', dpi=fig.dpi,bbox_inches='tight'),
