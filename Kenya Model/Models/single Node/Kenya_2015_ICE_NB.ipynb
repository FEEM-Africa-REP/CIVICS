# %%
import calliope
import Graphs as gg

# %%
try:
    calliope.set_log_level('INFO')
except:
    calliope.set_log_verbosity('INFO')
model = calliope.Model('model.yaml')
model.run()
# Out:
# [2020-06-14 16:49:19] INFO     Model: initialising
# [2020-06-14 16:49:19] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\calliope\core\preprocess\model_run.py:227: FutureWarning:
#
# There will be no default cost class for the objective function in v0.7.0 (currently "monetary" with a weight of 1). Explicitly specify the cost class(es) you would like to use under `run.objective_options.cost_class`. E.g. `{"monetary": 1}` to replicate the current default.
#
#
# [2020-06-14 16:49:19] INFO     Model: preprocessing stage 1 (model_run)
# [2020-06-14 16:49:21] INFO     NumExpr defaulting to 4 threads.
# [2020-06-14 16:49:21] INFO     Model: preprocessing stage 2 (model_data)
# [2020-06-14 16:49:30] INFO     Model: preprocessing complete
# [2020-06-14 16:49:30] INFO     Backend: starting model run
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
# ...

# %%
gg.Dispatch_sys(model,sp_tech=False,pie_values='value',weekly=True,Unit='GWh',rnd=0,font=12.5)
# Out:
# [2020-06-14 16:55:40] INFO     Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [2020-06-14 16:55:40] WARNING  C:\Users\Amin\Documents\GitHub\My Kenya\Kenya Model\Models\single Node\Graphs.py:590: MatplotlibDeprecationWarning:
#
# Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
