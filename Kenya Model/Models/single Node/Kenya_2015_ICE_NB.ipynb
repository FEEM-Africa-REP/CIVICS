# %%
import calliope
import Graphs as gg

# %%
try:
    calliope.set_log_level('INFO')
except:
    calliope.set_log_verbosity('INFO')
model = calliope.Model('model.yaml')
model.run()
# Out:
# [2020-06-13 14:32:35] INFO     Model: initialising
# [2020-06-13 14:32:36] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\calliope\core\preprocess\model_run.py:227: FutureWarning:
#
# There will be no default cost class for the objective function in v0.7.0 (currently "monetary" with a weight of 1). Explicitly specify the cost class(es) you would like to use under `run.objective_options.cost_class`. E.g. `{"monetary": 1}` to replicate the current default.
#
#
# [2020-06-13 14:32:36] INFO     Model: preprocessing stage 1 (model_run)
# [2020-06-13 14:32:36] INFO     NumExpr defaulting to 4 threads.
# [2020-06-13 14:32:36] INFO     Model: preprocessing stage 2 (model_data)
# [2020-06-13 14:32:36] INFO     Model: preprocessing complete
# [2020-06-13 14:32:36] INFO     Backend: starting model run
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lifetime) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lifetime) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_carriers) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_carriers) to be
# 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:38] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:39] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:39] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:39] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:39] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:39] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:39] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (max_demand_timesteps) to be 'Any', you
#     can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-13 14:32:39] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (max_demand_timesteps) to be
# 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# [2020-06-13 14:32:39] INFO     constraints are loaded in the following order: ['capacity', 'costs', 'dispatch', 'energy_balance', 'network', 'policy', 'conversion', 'conversion_plus', 'group', 'export', 'milp']
# [2020-06-13 14:32:39] INFO     Backend: model generated. Time since start of model run: 0:00:02.315195
# [2020-06-13 14:32:39] INFO     Backend: sending model to solver
# [2020-06-13 14:32:39] DEBUG    GLPSOL: GLPK LP/MIP Solver, v4.62
# [2020-06-13 14:32:39] DEBUG    Parameter(s) specified in the command line:
# [2020-06-13 14:32:39] DEBUG    --write C:\Users\Amin\AppData\Local\Temp\tmp9lbs3ji9.glpk.raw --wglp C:\Users\Amin\AppData\Local\Temp\tmpus85323u.glpk.glp
# [2020-06-13 14:32:39] DEBUG    --cpxlp C:\Users\Amin\AppData\Local\Temp\tmpdfwadj9u.pyomo.lp
# [2020-06-13 14:32:39] DEBUG    Reading problem data from 'C:\Users\Amin\AppData\Local\Temp\tmpdfwadj9u.pyomo.lp'...
# [2020-06-13 14:32:39] DEBUG    1223 rows, 889 columns, 2868 non-zeros
# [2020-06-13 14:32:39] DEBUG    7441 lines were read
# [2020-06-13 14:32:39] DEBUG    Writing problem data to 'C:\Users\Amin\AppData\Local\Temp\tmpus85323u.glpk.glp'...
# [2020-06-13 14:32:39] DEBUG    6164 lines were written
# [2020-06-13 14:32:39] DEBUG    GLPK Simplex Optimizer, v4.62
# [2020-06-13 14:32:39] DEBUG    1223 rows, 889 columns, 2868 non-zeros
# [2020-06-13 14:32:39] DEBUG    Preprocessing...
# [2020-06-13 14:32:39] DEBUG    288 rows, 434 columns, 864 non-zeros
# [2020-06-13 14:32:39] DEBUG    Scaling...
# [2020-06-13 14:32:39] DEBUG    A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# [2020-06-13 14:32:39] DEBUG    Problem data seem to be well scaled
# [2020-06-13 14:32:39] DEBUG    Constructing initial basis...
# [2020-06-13 14:32:39] DEBUG    Size of triangular part is 288
# [2020-06-13 14:32:39] DEBUG    0: obj =   1.419388023e+07 inf =   4.367e+07 (48)
# [2020-06-13 14:32:39] DEBUG    85: obj =   9.037042057e+06 inf =   0.000e+00 (0)
# [2020-06-13 14:32:39] DEBUG    *   374: obj =   4.748814889e+06 inf =   0.000e+00 (0)
# [2020-06-13 14:32:39] DEBUG    OPTIMAL LP SOLUTION FOUND
# [2020-06-13 14:32:39] DEBUG    Time used:   0.0 secs
# [2020-06-13 14:32:39] DEBUG    Memory used: 1.1 Mb (1125604 bytes)
# [2020-06-13 14:32:39] DEBUG    Writing basic solution to 'C:\Users\Amin\AppData\Local\Temp\tmp9lbs3ji9.glpk.raw'...
# [2020-06-13 14:32:39] DEBUG    2121 lines were written
# [2020-06-13 14:32:39] INFO     Backend: solver finished running. Time since start of model run: 0:00:02.777365
# [2020-06-13 14:32:39] INFO     Backend: loaded results
# [2020-06-13 14:32:39] INFO     Backend: generated solution array. Time since start of model run: 0:00:02.840198
# [2020-06-13 14:32:39] INFO     Postprocessing: started
# [2020-06-13 14:32:40] INFO     Postprocessing: zero threshold of 1e-20 not required
# [2020-06-13 14:32:40] INFO     Postprocessing: ended. Time since start of model run: 0:00:03.142391

# %%
gg.Dispatch_sys(model,sp_tech=False,pie_values='value')
# Out:
# [2020-06-13 14:32:40] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning:
#
# Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#
#
# [2020-06-13 14:32:41] WARNING  C:\Users\Amin\Documents\GitHub\My Kenya\Kenya Model\single Node\Graphs.py:584: MatplotlibDeprecationWarning:
#
# Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
