# %%
import calliope
import Graphs as gg

# %%
try:
    calliope.set_log_level('ERROR')
except:
    calliope.set_log_verbosity('ERROR')
model = calliope.Model('model.yaml')
model.run()
# Out:
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lifetime) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:13] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lifetime) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
# ...
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs_conversion) to be 'Any',
#     you can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs_conversion)
# to be 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs_conversion) to be 'Any',
#     you can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs_conversion)
# to be 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs_conversion) to be 'Any',
#     you can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs_conversion)
# to be 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs_conversion) to be 'Any',
#     you can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:19] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs_conversion)
# to be 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (max_demand_timesteps) to be 'Any', you
#     can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:20] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (max_demand_timesteps) to be
# 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (max_demand_timesteps) to be 'Any', you
#     can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:20] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (max_demand_timesteps) to be
# 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (max_demand_timesteps) to be 'Any', you
#     can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-06-19 12:06:20] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (max_demand_timesteps) to be
# 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# [2020-06-19 12:06:29] INFO     constraints are loaded in the following order: ['capacity', 'costs', 'dispatch', 'energy_balance', 'network', 'policy', 'conversion', 'conversion_plus', 'group', 'export', 'milp']
# [2020-06-19 12:12:34] DEBUG    Academic license - for non-commercial use only
# [2020-06-19 12:12:48] DEBUG    Read LP format model from file C:\Users\stevo\AppData\Local\Temp\tmpzbfnp91p.pyomo.lp
# [2020-06-19 12:12:48] DEBUG    Reading time = 14.34 seconds
# [2020-06-19 12:12:48] DEBUG    x1638349: 2531867 rows, 1638349 columns, 5921971 nonzeros
# [2020-06-19 12:13:09] DEBUG    35   9.22617500e+08  9.22604089e+08  1.53e-01 1.45e-10  1.46e-01    21s
# [2020-06-19 12:13:09] DEBUG    36   9.22618147e+08  9.22609473e+08  1.17e-01 1.29e-10  1.09e-01    21s
# [2020-06-19 12:13:09] DEBUG    37   9.22622766e+08  9.22617654e+08  4.55e-02 2.11e-10  4.60e-02    21s
# [2020-06-19 12:13:09] DEBUG    38   9.22624625e+08  9.22622212e+08  1.14e-02 3.27e-10  1.38e-02    21s
# [2020-06-19 12:13:09] DEBUG    39   9.22624824e+08  9.22623774e+08  4.69e-03 2.80e-10  5.80e-03    21s
# [2020-06-19 12:13:09] DEBUG    40   9.22624864e+08  9.22624550e+08  8.76e-04 1.64e-10  1.32e-03    21s
# [2020-06-19 12:13:09] DEBUG    41   9.22624831e+08  9.22624779e+08  1.22e-05 1.41e-10  1.14e-04    21s
# [2020-06-19 12:13:10] DEBUG    42   9.22624827e+08  9.22624823e+08  1.83e-06 4.22e-11  8.27e-06    22s
# [2020-06-19 12:13:10] DEBUG    43   9.22624826e+08  9.22624826e+08  2.07e-07 2.81e-11  1.43e-08    22s
# [2020-06-19 12:13:10] DEBUG    44   9.22624826e+08  9.22624826e+08  1.26e-10 3.41e-13  7.88e-12    22s
# [2020-06-19 12:13:10] DEBUG
# [2020-06-19 12:13:10] DEBUG    Barrier solved model in 44 iterations and 21.78 seconds
# [2020-06-19 12:13:10] DEBUG    Optimal objective 9.22624826e+08
# [2020-06-19 12:13:10] DEBUG
# [2020-06-19 12:13:10] DEBUG    Crossover log...
# [2020-06-19 12:13:10] DEBUG
# [2020-06-19 12:13:10] DEBUG    44 DPushes remaining with DInf 0.0000000e+00                22s
# [2020-06-19 12:13:10] DEBUG    0 DPushes remaining with DInf 6.9936895e-14                22s
# [2020-06-19 12:13:10] DEBUG
# [2020-06-19 12:13:10] DEBUG    5410 PPushes remaining with PInf 0.0000000e+00                22s
# [2020-06-19 12:13:10] DEBUG    0 PPushes remaining with PInf 0.0000000e+00                22s
# [2020-06-19 12:13:10] DEBUG
# [2020-06-19 12:13:10] DEBUG    Push phase complete: Pinf 0.0000000e+00, Dinf 6.9882251e-14     22s
# [2020-06-19 12:13:10] DEBUG
# [2020-06-19 12:13:10] DEBUG    Iteration    Objective       Primal Inf.    Dual Inf.      Time
# [2020-06-19 12:13:10] DEBUG    5457    9.2262483e+08   0.000000e+00   0.000000e+00     22s
# [2020-06-19 12:13:17] DEBUG    5457    9.2262483e+08   0.000000e+00   0.000000e+00     29s
# [2020-06-19 12:13:17] DEBUG
# [2020-06-19 12:13:17] DEBUG    Solved with dual simplex
# [2020-06-19 12:13:18] DEBUG    Solved in 65918 iterations and 29.43 seconds
# [2020-06-19 12:13:18] DEBUG    Optimal objective  9.226248263e+08
# [2020-06-19 12:13:18] DEBUG    Warning: unscaled primal violation = 7.38725e-06 and residual = 7.38725e-06

# %%
gg.Dispatch_sys(model,sp_tech='bio_coffee_pp',weekly=True,pie_values='share')
gg.Dispatch_reg(model,sp_tech=False,sp_reg=False,weekly=True,pie_values='share',rnd=1,font=13,rational='cons')
# Out:
# 1
# 1
