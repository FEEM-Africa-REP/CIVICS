# %%
import calliope

# %%
try:
    calliope.set_log_level('INFO')
except:
    calliope.set_log_verbosity('INFO')
model = calliope.Model('model.yaml')
model.run()
# Out:
# [2020-09-01 11:02:21] INFO     Model: initialising
# [2020-09-01 11:02:21] WARNING  C:\Users\payam\anaconda3\envs\calliope\lib\site-packages\calliope\core\preprocess\model_run.py:227: FutureWarning:
#
# There will be no default cost class for the objective function in v0.7.0 (currently "monetary" with a weight of 1). Explicitly specify the cost class(es) you would like to use under `run.objective_options.cost_class`. E.g. `{"monetary": 1}` to replicate the current default.
#
#
# [2020-09-01 11:02:21] INFO     Model: preprocessing stage 1 (model_run)
# [2020-09-01 11:02:22] INFO     Model: preprocessing stage 2 (model_data)
# [2020-09-01 11:02:22] INFO     Model: preprocessing complete
# [2020-09-01 11:02:22] INFO     Backend: starting model run
# [2020-09-01 11:02:22] INFO     constraints are loaded in the following order: ['capacity', 'costs', 'dispatch', 'energy_balance', 'network', 'policy', 'conversion', 'conversion_plus', 'group', 'export', 'milp']
# [2020-09-01 11:02:22] INFO     Backend: model generated. Time since start of model run: 0:00:00.427867
# [2020-09-01 11:02:22] INFO     Backend: sending model to solver
# [2020-09-01 11:02:23] DEBUG    GLPSOL: GLPK LP/MIP Solver, v4.62
# [2020-09-01 11:02:23] DEBUG    Parameter(s) specified in the command line:
# [2020-09-01 11:02:23] DEBUG    --write C:\Users\payam\AppData\Local\Temp\tmphjjyenne.glpk.raw --wglp C:\Users\payam\AppData\Local\Temp\tmp9iu8hrvr.glpk.glp
# [2020-09-01 11:02:23] DEBUG    --cpxlp C:\Users\payam\AppData\Local\Temp\tmp29b2f661.pyomo.lp
# [2020-09-01 11:02:23] DEBUG    Reading problem data from 'C:\Users\payam\AppData\Local\Temp\tmp29b2f661.pyomo.lp'...
# [2020-09-01 11:02:23] DEBUG    5754 rows, 4059 columns, 14380 non-zeros
# [2020-09-01 11:02:23] DEBUG    35739 lines were read
# [2020-09-01 11:02:23] DEBUG    Writing problem data to 'C:\Users\payam\AppData\Local\Temp\tmp9iu8hrvr.glpk.glp'...
# [2020-09-01 11:02:23] DEBUG    29909 lines were written
# [2020-09-01 11:02:23] DEBUG    GLPK Simplex Optimizer, v4.62
# [2020-09-01 11:02:23] DEBUG    5754 rows, 4059 columns, 14380 non-zeros
# [2020-09-01 11:02:23] DEBUG    Preprocessing...
# [2020-09-01 11:02:23] DEBUG    1248 rows, 2305 columns, 4368 non-zeros
# [2020-09-01 11:02:23] DEBUG    Scaling...
# [2020-09-01 11:02:23] DEBUG    A: min|aij| =  9.837e-01  max|aij| =  1.000e+00  ratio =  1.017e+00
# [2020-09-01 11:02:23] DEBUG    Problem data seem to be well scaled
# [2020-09-01 11:02:23] DEBUG    Constructing initial basis...
# [2020-09-01 11:02:23] DEBUG    Size of triangular part is 1248
# [2020-09-01 11:02:23] DEBUG    0: obj =   9.856638334e+06 inf =   2.143e+07 (97)
# [2020-09-01 11:02:23] DEBUG    234: obj =   8.106033269e+06 inf =   0.000e+00 (0)
# [2020-09-01 11:02:23] DEBUG    *   500: obj =   7.469168889e+06 inf =   0.000e+00 (307) 1
# [2020-09-01 11:02:23] DEBUG    *   864: obj =   4.767743878e+06 inf =   0.000e+00 (0) 2
# [2020-09-01 11:02:23] DEBUG    OPTIMAL LP SOLUTION FOUND
# [2020-09-01 11:02:23] DEBUG    Time used:   0.0 secs
# [2020-09-01 11:02:23] DEBUG    Memory used: 5.1 Mb (5338948 bytes)
# [2020-09-01 11:02:23] DEBUG    Writing basic solution to 'C:\Users\payam\AppData\Local\Temp\tmphjjyenne.glpk.raw'...
# [2020-09-01 11:02:23] DEBUG    9822 lines were written
# [2020-09-01 11:02:23] INFO     Backend: solver finished running. Time since start of model run: 0:00:00.994413
# [2020-09-01 11:02:23] INFO     Backend: loaded results
# [2020-09-01 11:02:23] INFO     Backend: generated solution array. Time since start of model run: 0:00:01.039293
# [2020-09-01 11:02:23] INFO     Postprocessing: started
# [2020-09-01 11:02:23] INFO     Postprocessing: zero threshold of 1e-20 not required
# [2020-09-01 11:02:23] INFO     Postprocessing: ended. Time since start of model run: 0:00:01.188936

# %%
import cal_graph as CG
amin=CG.C_Graph(model=model,ex_path=r'Graph_inputs.xlsx',unit='kW')

# %%
amin.production.index

# %%
amin.node_dispatch(unit='GW',average='hourly',x_ticks='date',fig_format='svg')

# %%
#amin.cap_f_plot(v_round=3)
amin.ins_cap_plot(kind='bar')

# %%
amin.node_pie(unit='GW',v_round=3,rational='consumption',kind='absolute',style='ggplot')

# %%
amin.demand

# %%
import pandas as pd

# %%
a= pd.read_excel(r'C:\Users\Amin\Documents\GitHub\My Kenya\Calliope_Kenya\Models\4Nodes_No-Coffee\Time_series_data\Book1.xlsx',header=[0],index_col=[0])

# %%
a.index

# %%
def date2name(date,name):
    
    l_date=[]
    l_name=[]
    l_date.append(date[0])
    l_name.append(name[0])    
    
    for i in range(1,len(date)):
        if name[i] != name[i-1]:

            l_date.append(date[i])
            l_name.append(name[i])
    
    return l_date,l_name

# %%
qq=date2name(amin.production.index,amin.production.index.month_name())

# %%
qq

# %%
amin.production

# %%
amin.production.plot(kind='area')

# %%
import matplotlib.pyplot as plt
fig,(ax) = plt.subplots(1)
ax.margins(x=0)
ax.margins(y=0.1)
            
# Drawing demand line
plt.plot(a.index,a.values,'#000000',alpha=0.5, linestyle = '-', label ='Demand',linewidth=0.5)
            

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.,frameon=True)
            
            
# labels
plt.xlabel('Date')

            

ticks = date2name(list(a.index),list(a.index.month_name()))
plt.xticks(ticks =ticks[0] ,labels = ticks[1], rotation = 70)
ax.set_xticks(ax.get_xticks()[0:12])
