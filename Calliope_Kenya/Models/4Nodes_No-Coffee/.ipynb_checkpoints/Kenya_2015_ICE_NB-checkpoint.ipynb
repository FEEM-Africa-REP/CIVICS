# %%
import calliope
import Graphs as gg

# %%
try:
    calliope.set_log_level('INFO')
except:
    calliope.set_log_verbosity('INFO')
model = calliope.Model('model.yaml')
model.run()
# Out:
# [2020-06-14 16:45:25] INFO     Model: initialising
# [2020-06-14 16:45:25] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\calliope\core\preprocess\model_run.py:227: FutureWarning:
#
# There will be no default cost class for the objective function in v0.7.0 (currently "monetary" with a weight of 1). Explicitly specify the cost class(es) you would like to use under `run.objective_options.cost_class`. E.g. `{"monetary": 1}` to replicate the current default.
#
#
# [2020-06-14 16:45:26] INFO     Model: preprocessing stage 1 (model_run)
# [2020-06-14 16:45:26] INFO     NumExpr defaulting to 4 threads.
# [2020-06-14 16:45:26] INFO     Model: preprocessing stage 2 (model_data)
# [2020-06-14 16:45:26] INFO     Model: preprocessing complete
# [2020-06-14 16:45:26] INFO     Backend: starting model run
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
# ...

# %%
gg.Dispatch_sys(model,sp_tech=False,pie_values='value',Unit='GWh',rnd=1,font=15)
#gg.Dispatch_reg(model,sp_tech=False,sp_reg=False,weekly=False,pie_values='value',Unit='TWh',round=)
# Out:
# [2020-06-14 16:45:32] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning:
#
# Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#
#
# [2020-06-14 16:45:32] WARNING  C:\Users\Amin\Documents\GitHub\My Kenya\Kenya Model\Models\without coffee\Graphs.py:590: MatplotlibDeprecationWarning:
#
# Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
a
