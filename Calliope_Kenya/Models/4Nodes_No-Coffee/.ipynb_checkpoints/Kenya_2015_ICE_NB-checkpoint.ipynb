# %%
import calliope

# %%
try:
    calliope.set_log_level('INFO')
except:
    calliope.set_log_verbosity('INFO')
model = calliope.Model('model.yaml')
model.run()
# Out:
# [2020-08-31 16:57:13] INFO     Model: initialising
# [2020-08-31 16:57:13] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\calliope\core\preprocess\model_run.py:227: FutureWarning:
#
# There will be no default cost class for the objective function in v0.7.0 (currently "monetary" with a weight of 1). Explicitly specify the cost class(es) you would like to use under `run.objective_options.cost_class`. E.g. `{"monetary": 1}` to replicate the current default.
#
#
# [2020-08-31 16:57:13] INFO     Model: preprocessing stage 1 (model_run)
# [2020-08-31 16:57:14] INFO     NumExpr defaulting to 4 threads.
# [2020-08-31 16:57:14] INFO     Model: preprocessing stage 2 (model_data)
# [2020-08-31 16:57:14] INFO     Model: preprocessing complete
# [2020-08-31 16:57:14] INFO     Backend: starting model run
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lifetime) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lifetime) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# ...
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (max_demand_timesteps) to be 'Any', you
#     can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-31 16:57:16] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (max_demand_timesteps) to be
# 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# [2020-08-31 16:57:16] INFO     constraints are loaded in the following order: ['capacity', 'costs', 'dispatch', 'energy_balance', 'network', 'policy', 'conversion', 'conversion_plus', 'group', 'export', 'milp']
# [2020-08-31 16:57:17] INFO     Backend: model generated. Time since start of model run: 0:00:02.843663
# [2020-08-31 16:57:17] INFO     Backend: sending model to solver
# [2020-08-31 16:57:18] DEBUG    GLPSOL: GLPK LP/MIP Solver, v4.62
# [2020-08-31 16:57:18] DEBUG    Parameter(s) specified in the command line:
# [2020-08-31 16:57:18] DEBUG    --write C:\Users\Amin\AppData\Local\Temp\tmpmtg4rfnz.glpk.raw --wglp C:\Users\Amin\AppData\Local\Temp\tmp57ey_9do.glpk.glp
# [2020-08-31 16:57:18] DEBUG    --cpxlp C:\Users\Amin\AppData\Local\Temp\tmpcxqzt7hm.pyomo.lp
# [2020-08-31 16:57:18] DEBUG    Reading problem data from 'C:\Users\Amin\AppData\Local\Temp\tmpcxqzt7hm.pyomo.lp'...
# [2020-08-31 16:57:18] DEBUG    5754 rows, 4059 columns, 14380 non-zeros
# [2020-08-31 16:57:18] DEBUG    35739 lines were read
# [2020-08-31 16:57:18] DEBUG    Writing problem data to 'C:\Users\Amin\AppData\Local\Temp\tmp57ey_9do.glpk.glp'...
# [2020-08-31 16:57:18] DEBUG    29909 lines were written
# [2020-08-31 16:57:18] DEBUG    GLPK Simplex Optimizer, v4.62
# [2020-08-31 16:57:18] DEBUG    5754 rows, 4059 columns, 14380 non-zeros
# [2020-08-31 16:57:18] DEBUG    Preprocessing...
# [2020-08-31 16:57:18] DEBUG    1248 rows, 2305 columns, 4368 non-zeros
# [2020-08-31 16:57:18] DEBUG    Scaling...
# [2020-08-31 16:57:18] DEBUG    A: min|aij| =  9.837e-01  max|aij| =  1.000e+00  ratio =  1.017e+00
# [2020-08-31 16:57:18] DEBUG    Problem data seem to be well scaled
# [2020-08-31 16:57:18] DEBUG    Constructing initial basis...
# [2020-08-31 16:57:18] DEBUG    Size of triangular part is 1248
# [2020-08-31 16:57:18] DEBUG    0: obj =   9.856638334e+06 inf =   2.143e+07 (97)
# [2020-08-31 16:57:18] DEBUG    234: obj =   8.106033269e+06 inf =   0.000e+00 (0)
# [2020-08-31 16:57:18] DEBUG    *   500: obj =   7.469168889e+06 inf =   0.000e+00 (307) 1
# [2020-08-31 16:57:18] DEBUG    *   864: obj =   4.767743878e+06 inf =   0.000e+00 (0) 2
# [2020-08-31 16:57:18] DEBUG    OPTIMAL LP SOLUTION FOUND
# [2020-08-31 16:57:18] DEBUG    Time used:   0.1 secs
# [2020-08-31 16:57:18] DEBUG    Memory used: 5.1 Mb (5338948 bytes)
# [2020-08-31 16:57:18] DEBUG    Writing basic solution to 'C:\Users\Amin\AppData\Local\Temp\tmpmtg4rfnz.glpk.raw'...
# [2020-08-31 16:57:18] DEBUG    9822 lines were written
# [2020-08-31 16:57:18] INFO     Backend: solver finished running. Time since start of model run: 0:00:03.927640
# [2020-08-31 16:57:18] INFO     Backend: loaded results
# [2020-08-31 16:57:18] INFO     Backend: generated solution array. Time since start of model run: 0:00:04.005432
# [2020-08-31 16:57:18] INFO     Postprocessing: started
# [2020-08-31 16:57:18] INFO     Postprocessing: zero threshold of 1e-20 not required
# [2020-08-31 16:57:18] INFO     Postprocessing: ended. Time since start of model run: 0:00:04.291667

# %%
import cal_graph as CG
amin=CG.C_Graph(model=model,ex_path=r'Graph_inputs.xlsx',unit='kW')
# Out:
# C_Graph: A python class for customizing calliope outputs developed in Fondazione Eni Enrico Mattei.
#  Version 0.1: (Single Carrier)

# %%
amin.production.index

# %%
amin.node_dispatch(unit='GW',average='hourly',x_ticks='name',fig_format='svg')
# Out:
# [2020-08-31 16:57:19] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning:
#
# Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()

# %%
#amin.cap_f_plot(v_round=3)
amin.ins_cap_plot(kind='bar')

# %%
amin.node_pie(unit='GW',v_round=2,rational='consumption')

# %%
amin.demand

# %%
import pandas as pd

# %%
a= pd.read_excel(r'C:\Users\Amin\Documents\GitHub\My Kenya\Calliope_Kenya\Models\4Nodes_No-Coffee\Time_series_data\Book1.xlsx',header=[0],index_col=[0])

# %%
a.index

# %%
def date2name(date,name):
    
    l_date=[]
    l_name=[]
    l_date.append(date[0])
    l_name.append(name[0])    
    
    for i in range(1,len(date)):
        if name[i] != name[i-1]:

            l_date.append(date[i])
            l_name.append(name[i])
    
    return l_date,l_name

# %%
qq=date2name(amin.production.index,amin.production.index.month_name())

# %%
qq

# %%
amin.production

# %%
amin.production.plot(kind='area')

# %%
import matplotlib.pyplot as plt
fig,(ax) = plt.subplots(1)
ax.margins(x=0)
ax.margins(y=0.1)
            
# Drawing demand line
plt.plot(a.index,a.values,'#000000',alpha=0.5, linestyle = '-', label ='Demand',linewidth=0.5)
            

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.,frameon=True)
            
            
# labels
plt.xlabel('Date')

            

ticks = date2name(list(a.index),list(a.index.month_name()))
plt.xticks(ticks =ticks[0] ,labels = ticks[1], rotation = 70)
ax.set_xticks(ax.get_xticks()[0:12])
