# %%
import calliope

# %%
try:
    calliope.set_log_level('INFO')
except:
    calliope.set_log_verbosity('INFO')
model = calliope.Model('model.yaml')
model.run()
# Out:
# [2020-08-18 17:34:31] INFO     Model: initialising
# [2020-08-18 17:34:31] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\calliope\core\preprocess\model_run.py:227: FutureWarning:
#
# There will be no default cost class for the objective function in v0.7.0 (currently "monetary" with a weight of 1). Explicitly specify the cost class(es) you would like to use under `run.objective_options.cost_class`. E.g. `{"monetary": 1}` to replicate the current default.
#
#
# [2020-08-18 17:34:32] INFO     Model: preprocessing stage 1 (model_run)
# [2020-08-18 17:34:32] INFO     NumExpr defaulting to 4 threads.
# [2020-08-18 17:34:32] INFO     Model: preprocessing stage 2 (model_data)
# [2020-08-18 17:34:32] INFO     Model: preprocessing complete
# [2020-08-18 17:34:33] INFO     Backend: starting model run
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (resource_unit) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (resource_unit) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lifetime) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lifetime) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_remotes) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_remotes) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (colors) to be 'Any', you can suppress
#     this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (colors) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (inheritance) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (inheritance) to be 'Any', you
# can suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (names) to be 'Any', you can
# suppress this warning by explicitly specifying 'within=Any' to the
# Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (names) to be 'Any', you can suppress this
#     warning by explicitly specifying 'within=Any' to the Param constructor.
#     (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# ...
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (lookup_loc_techs) to be 'Any', you can
#     suppress this warning by explicitly specifying 'within=Any' to the Param
#     constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (lookup_loc_techs) to be 'Any',
# you can suppress this warning by explicitly specifying 'within=Any' to
# the Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# WARNING: DEPRECATED: The default domain for Param objects is 'Any'.  However,
#     we will be changing that default to 'Reals' in the future.  If you really
#     intend the domain of this Param (max_demand_timesteps) to be 'Any', you
#     can suppress this warning by explicitly specifying 'within=Any' to the
#     Param constructor.  (deprecated in 5.6.9, will be removed in 6.0)
# [2020-08-18 17:34:35] WARNING  DEPRECATED: The default domain for Param objects is 'Any'.  However,
# we will be changing that default to 'Reals' in the future.  If you
# really intend the domain of this Param (max_demand_timesteps) to be
# 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will be
# removed in 6.0)
# [2020-08-18 17:34:35] INFO     constraints are loaded in the following order: ['capacity', 'costs', 'dispatch', 'energy_balance', 'network', 'policy', 'conversion', 'conversion_plus', 'group', 'export', 'milp']
# [2020-08-18 17:34:36] INFO     Backend: model generated. Time since start of model run: 0:00:03.740505
# [2020-08-18 17:34:36] INFO     Backend: sending model to solver
# [2020-08-18 17:34:37] DEBUG    GLPSOL: GLPK LP/MIP Solver, v4.62
# [2020-08-18 17:34:37] DEBUG    Parameter(s) specified in the command line:
# [2020-08-18 17:34:37] DEBUG    --write C:\Users\Amin\AppData\Local\Temp\tmpzsfmpluo.glpk.raw --wglp C:\Users\Amin\AppData\Local\Temp\tmp55ifvizw.glpk.glp
# [2020-08-18 17:34:37] DEBUG    --cpxlp C:\Users\Amin\AppData\Local\Temp\tmpncx2mofk.pyomo.lp
# [2020-08-18 17:34:37] DEBUG    Reading problem data from 'C:\Users\Amin\AppData\Local\Temp\tmpncx2mofk.pyomo.lp'...
# [2020-08-18 17:34:37] DEBUG    5754 rows, 4059 columns, 14380 non-zeros
# [2020-08-18 17:34:37] DEBUG    35739 lines were read
# [2020-08-18 17:34:37] DEBUG    Writing problem data to 'C:\Users\Amin\AppData\Local\Temp\tmp55ifvizw.glpk.glp'...
# [2020-08-18 17:34:37] DEBUG    29909 lines were written
# [2020-08-18 17:34:37] DEBUG    GLPK Simplex Optimizer, v4.62
# [2020-08-18 17:34:37] DEBUG    5754 rows, 4059 columns, 14380 non-zeros
# [2020-08-18 17:34:37] DEBUG    Preprocessing...
# [2020-08-18 17:34:37] DEBUG    1248 rows, 2305 columns, 4368 non-zeros
# [2020-08-18 17:34:37] DEBUG    Scaling...
# [2020-08-18 17:34:37] DEBUG    A: min|aij| =  9.837e-01  max|aij| =  1.000e+00  ratio =  1.017e+00
# [2020-08-18 17:34:37] DEBUG    Problem data seem to be well scaled
# [2020-08-18 17:34:37] DEBUG    Constructing initial basis...
# [2020-08-18 17:34:37] DEBUG    Size of triangular part is 1248
# [2020-08-18 17:34:37] DEBUG    0: obj =   9.856638334e+06 inf =   2.143e+07 (97)
# [2020-08-18 17:34:37] DEBUG    234: obj =   8.106033269e+06 inf =   0.000e+00 (0)
# [2020-08-18 17:34:37] DEBUG    *   500: obj =   7.469168889e+06 inf =   0.000e+00 (307) 1
# [2020-08-18 17:34:37] DEBUG    *   864: obj =   4.767743878e+06 inf =   0.000e+00 (0) 2
# [2020-08-18 17:34:37] DEBUG    OPTIMAL LP SOLUTION FOUND
# [2020-08-18 17:34:37] DEBUG    Time used:   0.1 secs
# [2020-08-18 17:34:37] DEBUG    Memory used: 5.1 Mb (5338948 bytes)
# [2020-08-18 17:34:37] DEBUG    Writing basic solution to 'C:\Users\Amin\AppData\Local\Temp\tmpzsfmpluo.glpk.raw'...
# [2020-08-18 17:34:37] DEBUG    9822 lines were written
# [2020-08-18 17:34:37] INFO     Backend: solver finished running. Time since start of model run: 0:00:04.897890
# [2020-08-18 17:34:37] INFO     Backend: loaded results
# [2020-08-18 17:34:38] INFO     Backend: generated solution array. Time since start of model run: 0:00:04.995708
# [2020-08-18 17:34:38] INFO     Postprocessing: started
# [2020-08-18 17:34:38] INFO     Postprocessing: zero threshold of 1e-20 not required
# [2020-08-18 17:34:38] INFO     Postprocessing: ended. Time since start of model run: 0:00:05.345569

# %%
import cal_graph as CG
amin=CG.C_Graph(model=model,ex_path=r'C:\Users\Amin\Documents\GitHub\My Kenya\Calliope_Kenya\Models\4Nodes_No-Coffee\Graph_inputs.xlsx',unit='kWh')
amin.node_dispatch(nodes=['WSTR'],unit='GWh',title_font=20,average='weekly')

# %%
amin.a.plot(kind='area')

# %%
import pandas as pd

# %%
Dem_Tech = pd.read_excel('Graph_inputs.xlsx',sheet_name = 'Consumption Techs',index_col=[0],header=[0])
Nodes    = pd.read_excel('Graph_inputs.xlsx',sheet_name = 'Nodes',index_col=[0],header=[0])
Pr_Techs = pd.read_excel('Graph_inputs.xlsx',sheet_name = 'Production Techs',index_col = [0],header=[0])
colname  = pd.read_excel('Graph_inputs.xlsx',sheet_name = 'Col_Name',index_col = [0],header =[0])
imp_exp  = pd.read_excel('Graph_inputs.xlsx',sheet_name = 'imp-exp',index_col = [0],header =[0])
Trans    = pd.read_excel('Graph_inputs.xlsx',sheet_name = 'Transmission',index_col = [0],header =[0])
date     = pd.read_excel('Graph_inputs.xlsx',sheet_name = 'Date',index_col = [0],header =[0])

# %%
co_techs = Dem_Tech['Tech'].to_list()
carr     = Dem_Tech['Carrier'].to_list()
nodes    = Nodes['Location'].to_list()
pr_techs = Pr_Techs['Tech'].to_list()
colors   = colname['Color']
names    = colname['Name']
imps     = imp_exp['Imports'].to_list()
exps     = imp_exp['Exports'].to_list()
tr_tech  = Trans['Tech'].to_list()
start    = date['Value'][0]
end      = date['Value'][1]

# %%
carr

# %%
# How to build the transmissions

# %%
RES_ind = []
for i in range(len(pr_techs)):
    if Pr_Techs['RES'][i] == 1:
        RES_ind.append('Renewable')
    else:
        RES_ind.append('Conventional')

# %%
RES_ind = RES_ind * len(nodes)

# %%
model.get_formatted_array('carrier_prod').loc[{'techs':pr_techs,'carriers':'power','locs':nodes}].to_pandas().T

# %%
pr = model.get_formatted_array('carrier_prod').loc[{'techs':pr_techs,'carriers':'power','locs':[nodes[0]]}].sum('locs').to_pandas().T
pr = pd.concat([pr],keys=[nodes[0]],axis=1)
for i in  range (1,len(nodes)):
    pr0 = model.get_formatted_array('carrier_prod').loc[{'techs':pr_techs,'carriers':'power','locs':[nodes[i]]}].sum('locs').to_pandas().T
    pr0 = pd.concat([pr0],keys=[nodes[i]],axis=1)
    pr = pd.concat([pr,pr0],axis=1)

# %%
# Out:
# Index(['geo_pp', 'L_hydro_pp', 'S_hydro_pp', 'on_wind_pp', 'HFO_pp', 'GT_pp',
#        'bio_pp'],
#       dtype='object', name='techs')

# %%
node = nodes[0]

r_nodes = nodes.copy()
r_nodes.remove(node)

exp = r_nodes.copy()
imp = r_nodes.copy()
    
node_index = []
    
for j in range(len(r_nodes)):
        
    node_index.append(nodes[0]) 
    node_index.append(nodes[0]) 
        
    exp[j] = exp[j] + '_exp'
    imp[j] = imp[j] + '_imp'

exports = pd.DataFrame(index=pr.index,columns=exp)
imports = pd.DataFrame(index=pr.index,columns=imp)


tran_get = []

for i in r_nodes:
    tr = []
    for j in tr_tech:
        tr.append(j + ':' + i)
    tran_get.append(tr)

for i in range(len(exp)):
    exports[exp[i]] = model.get_formatted_array('carrier_con').loc[{'techs':tran_get[i],'carriers':carr,'locs':[node]}].sum('locs').sum('techs').to_pandas().T
    imports[imp[i]] = model.get_formatted_array('carrier_prod').loc[{'techs':tran_get[i],'carriers':carr,'locs':[node]}].sum('locs').sum('techs').to_pandas().T

imports = pd.concat([imports],keys=[node],axis=1)
exports = pd.concat([exports],keys=[node],axis=1)
    
for i in range(1,len(nodes)):
    node = nodes[i]
    r_nodes = nodes.copy()
    r_nodes.remove(node)
    
    
    exp = r_nodes.copy()
    imp = r_nodes.copy()
    
    node_index = []
    
    for j in range(len(r_nodes)):
        
        node_index.append(nodes[i]) 
        node_index.append(nodes[i]) 
        
        exp[j] = exp[j] + '_exp'
        imp[j] = imp[j] + '_imp'   
        
    exports0 = pd.DataFrame(0,index=pr.index,columns=exp)
    imports0 = pd.DataFrame(0,index=pr.index,columns=imp)
    

    tran_get = []

    for h in r_nodes:
        tr = []
        for p in tr_tech:
            tr.append(p + ':' + h)
        tran_get.append(tr)

    for n in range(len(exp)):
        exports0[exp[n]] = model.get_formatted_array('carrier_con').loc[{'techs':tran_get[n],'carriers':carr,'locs':[node]}].sum('locs').sum('techs').to_pandas().T
        imports0[imp[n]] = model.get_formatted_array('carrier_prod').loc[{'techs':tran_get[n],'carriers':carr,'locs':[node]}].sum('locs').sum('techs').to_pandas().T

    imports0 = pd.concat([imports0],keys=[node],axis=1)
    exports0 = pd.concat([exports0],keys=[node],axis=1)
    
    imports = pd.concat([imports,imports0],axis=1)
    exports = pd.concat([exports,exports0],axis=1)

# %%
demand = -model.get_formatted_array('carrier_con').loc[{'techs':co_techs,'carriers':carr,'locs':nodes}].sum('techs').sum('carriers').to_pandas().T

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import gridspec
plt.style.use('seaborn-colorblind')

col_list_pr = []
name_list_pr = []

prod = pd.concat([pr['WSTR'],imports['WSTR']],axis=1)


fig, (ax1) = plt.subplots(1, figsize=(8,6))
ax1.margins(x=0)
ax1.margins(y=0.1)

plt.plot(demand['WSTR'].index,demand['WSTR'].values,'black', alpha=0.5, linestyle = '--', label ='Demand',linewidth=3)

plt.stackplot(pr['WSTR'].index,pr['WSTR'].values.T,colors=colors[prod.columns],labels=names[prod.columns])

plt.stackplot(pr['WSTR'].index,exports['WSTR'].values.T,colors=colors[exports['WSTR'].columns],labels=names[exports['WSTR'].columns])

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.,frameon=True)
plt.title("Electricity Production",fontsize=15)

#plt.yticks(fontweight='bold')

xfmt = mdates.DateFormatter('%d/%m/%y , %H:%M')
ax1.xaxis.set_major_formatter(xfmt)

plt.xlabel('Date')
plt.xticks(rotation=70)
plt.savefig('Graphs\Pie_System_Result.{}'.format('png'), dpi=fig.dpi,bbox_inches='tight')

# %%
converter = {'Wh':1,'kWh':10**3,'MWh':10**6,'GWh':10**9,'TWh':10**12}

# %%
unit1,unit2= 'Wh','kWh'

# %%
converter[unit2]/converter[unit1]

# %%
units = ['Wh','kWh','MWh','GWh','TWh']
a='ah'

print('{} hi'.format(units))

# %%
sp_tech=['bio_pp']
fig, (axs) = plt.subplots(2, figsize=(8,10),sharex=True)
gs = gridspec.GridSpec(2, 1,height_ratios=[3,1]) 
axs[1] = plt.subplot(gs[1])
axs[0] = plt.subplot(gs[0],sharex=axs[1])
plt.setp(axs[0].get_xticklabels(), visible=False)
col_list_pr = []
name_list_pr = []
prod = pd.concat([pr['WSTR'],imports['WSTR']],axis=1)



axs[0].margins(x=0)
axs[0].margins(y=0.1)

axs[0].plot(demand['WSTR'][start:end].index,demand['WSTR'][start:end].values,'black', alpha=0.5, linestyle = '--', label ='Demand',linewidth=3)

axs[0].stackplot(pr['WSTR'].index,pr['WSTR'].values.T,colors=colors[prod.columns],labels=names[prod.columns])

axs[0].stackplot(pr['WSTR'].index,exports['WSTR'].values.T,colors=colors[exports['WSTR'].columns],labels=names[exports['WSTR'].columns])

axs[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.,frameon=True)
plt.title("Electricity Production",fontsize=15)

axs[1].stackplot(pr['WSTR'].index,pr['WSTR'][sp_tech].values.T,colors=colors[sp_tech])

plt.yticks(fontweight='bold')

xfmt = mdates.DateFormatter('%d/%m/%y , %H:%M')
#axs.xaxis.set_major_formatter(xfmt)


#axs.xticks(rotation=70)

# %%
plt.figure(figsize=(8,8))

plt.pie(pr['WSTR'].sum(),shadow=False,colors=colors[pr_techs])

table = plt.table(cellText=pie.values,
                              rowColours=colors[pr_techs],
                              rowLabels= names[pr_techs],
                              colLabels = ['GWh'],
                              loc='right',
                              rowLoc ='center',
                              colLoc='center',
                              cellLoc='center',bbox=(1.25,0.2,0.1,0.5)) 
the_table.auto_set_font_size(False)
the_table.set_fontsize(15)

# %%
from fpdf import FPDF

# %%
class PDF(FPDF):
    pass

# %%
pdf =PDF()

# %%
pdf=PDF(orientation='L')
pdf=PDF(unit='mm') #unit of measurement
pdf=PDF(format='A4')
pdf.add_page()


# size of an A4 paper: W:210 , h:297
pdf_w = 210
pdf_h = 297

pdf.set_xy(0.0,0.0)
pdf.set_font('Arial','B',16)
pdf.set_text_color(220,50,50)
pdf.cell(w=210.0, h=40.0, align='C', txt="Summary of the Model", border=0)

pdf.set_xy(40.0,25.0)
#pdf.image(r'C:\Users\Amin\Documents\GitHub\My Kenya\Calliope_Kenya\Models\4Nodes_No-Coffee\Graphs\MTKR_16OP.png',  link='', type='', w=700/5, h=450/5)
data = [[' '],
        ['Mike', 'Driscoll', 'mike@somewhere.com', '55555'],
        ['John', 'Doe', 'jdoe@doe.com', '12345'],
        ['Nina', 'Ma', 'inane@where.com', '54321']
            ]
col_width = pdf.w / 4.5
pdf.set_font("Arial", size=12)
row_height = pdf.font_size
for row in data:
    for item in row:
        pdf.cell(col_width, row_height*1,
                     txt=item, border=1)
    pdf.ln(row_height*1)
pdf.output('test.pdf','F')

# %%
energy_cap=model.get_formatted_array('energy_cap_equals').loc[{'techs':pr_techs,'locs':nodes}].to_pandas().T

# %%
energy_cap=energy_cap.fillna(0)

# %%
energy_cap

# %%
nodes

# %%
plt.figure(figsize=(8,8))
table = plt.table(cellText=energy_cap.values,
                              rowColours=colors[pr_techs],
                              rowLabels= names[pr_techs],
                              colLabels = nodes,
                              loc='upper center',
                              rowLoc ='center',
                              colLoc='center',
                              cellLoc='center')
table.auto_set_font_size(True)
table.set_fontsize(15)
table.scale(1, 1.8)
plt.box(on=None)
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.title('Installed Capacity',fontsize=20)

plt.savefig('pyplot-table-figure-style.png',
            bbox_inches='tight',
            dpi=150
            )

# %%
cap_f=model.get_formatted_array('capacity_factor').loc[{'techs':pr_techs,'locs':['WSTR'],'carriers':'power'}].sum('locs').to_pandas().T

# %%
cap_f=cap_f.sum()/len(cap_f)

# %%
cap_f.plot(kind='bar',colors=colors[pr_techs])

# %%
a = model.get_formatted_array('cost').loc[{'techs':pr_techs,'locs':['WSTR'],'costs':'monetary'}].sum('locs').to_pandas().T

# %%
a.plot(kind='bar',stacked=True)

# %%
import cal_graph as CG
amin=CG.C_Graph(model=model,ex_path=r'C:\Users\Amin\Documents\GitHub\My Kenya\Calliope_Kenya\Models\4Nodes_No-Coffee\Graph_inputs.xlsx',unit='kWh')
amin.node_dispatch(unit='GWh')

# %%
amin.node_dispatch(unit='GWh')

# %%
pr['WSTR']

# %%
pr['WSTR'].resample('1h').mean()

# %%
pr.columns = [pr.columns.get_level_values(0),RES_ind]

# %%
pr=pr.groupby(level=[0,1],axis=1).sum()

# %%
shares = pd.DataFrame(0,index = pr.index , columns = pr.columns)

# %%
for i in nodes:
    shares[(i,'Renewable')] = pr[(i,'Renewable')] / pr[i].sum(axis=1)
    shares[(i,'Conventional')] = pr[(i,'Conventional')] / pr[i].sum(axis=1)

# %%
a=pr[('CSTR','Conventional')]

# %%
b=pr['CSTR'].sum(axis=1)

# %%
shares*100
# Out:
#                             CSTR                   MTKR            \
#                     Conventional Renewable Conventional Renewable
# timesteps
# 2015-01-01 00:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 01:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 02:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 03:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 04:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 05:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 06:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 07:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 08:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 09:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 10:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 11:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 12:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 13:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 14:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 15:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 16:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 17:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 18:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 19:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 20:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 21:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 22:00:00          NaN       NaN          0.0     100.0
# 2015-01-01 23:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 00:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 01:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 02:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 03:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 04:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 05:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 06:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 07:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 08:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 09:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 10:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 11:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 12:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 13:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 14:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 15:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 16:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 17:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 18:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 19:00:00        100.0       0.0          0.0     100.0
# 2015-01-02 20:00:00        100.0       0.0          0.0     100.0
# 2015-01-02 21:00:00        100.0       0.0          0.0     100.0
# 2015-01-02 22:00:00          NaN       NaN          0.0     100.0
# 2015-01-02 23:00:00          NaN       NaN          0.0     100.0
#
#                             NBOR                   WSTR
#                     Conventional Renewable Conventional Renewable
# timesteps
# 2015-01-01 00:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 01:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 02:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 03:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 04:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 05:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 06:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 07:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 08:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 09:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 10:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 11:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 12:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 13:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 14:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 15:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 16:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 17:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 18:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 19:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 20:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 21:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 22:00:00          0.0     100.0          0.0     100.0
# 2015-01-01 23:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 00:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 01:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 02:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 03:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 04:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 05:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 06:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 07:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 08:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 09:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 10:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 11:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 12:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 13:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 14:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 15:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 16:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 17:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 18:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 19:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 20:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 21:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 22:00:00          0.0     100.0          0.0     100.0
# 2015-01-02 23:00:00          0.0     100.0          0.0     100.0

# %%
pr['CSTR']
# Out:
# techs                geo_pp  L_hydro_pp  S_hydro_pp  on_wind_pp  \
# timesteps
# 2015-01-01 00:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 01:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 02:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 03:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 04:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 05:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 06:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 07:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 08:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 09:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 10:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 11:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 12:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 13:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 14:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 15:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 16:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 17:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 18:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 19:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 20:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 21:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 22:00:00     0.0         0.0         0.0         0.0
# 2015-01-01 23:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 00:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 01:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 02:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 03:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 04:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 05:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 06:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 07:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 08:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 09:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 10:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 11:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 12:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 13:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 14:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 15:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 16:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 17:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 18:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 19:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 20:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 21:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 22:00:00     0.0         0.0         0.0         0.0
# 2015-01-02 23:00:00     0.0         0.0         0.0         0.0
#
# techs                       HFO_pp  GT_pp  bio_pp
# timesteps
# 2015-01-01 00:00:00       0.000000    0.0     0.0
# 2015-01-01 01:00:00       0.000000    0.0     0.0
# 2015-01-01 02:00:00       0.000000    0.0     0.0
# 2015-01-01 03:00:00       0.000000    0.0     0.0
# 2015-01-01 04:00:00       0.000000    0.0     0.0
# 2015-01-01 05:00:00       0.000000    0.0     0.0
# 2015-01-01 06:00:00       0.000000    0.0     0.0
# 2015-01-01 07:00:00       0.000000    0.0     0.0
# 2015-01-01 08:00:00       0.000000    0.0     0.0
# 2015-01-01 09:00:00       0.000000    0.0     0.0
# 2015-01-01 10:00:00       0.000000    0.0     0.0
# 2015-01-01 11:00:00       0.000000    0.0     0.0
# 2015-01-01 12:00:00       0.000000    0.0     0.0
# 2015-01-01 13:00:00       0.000000    0.0     0.0
# 2015-01-01 14:00:00       0.000000    0.0     0.0
# 2015-01-01 15:00:00       0.000000    0.0     0.0
# 2015-01-01 16:00:00       0.000000    0.0     0.0
# 2015-01-01 17:00:00       0.000000    0.0     0.0
# 2015-01-01 18:00:00       0.000000    0.0     0.0
# 2015-01-01 19:00:00       0.000000    0.0     0.0
# 2015-01-01 20:00:00       0.000000    0.0     0.0
# 2015-01-01 21:00:00       0.000000    0.0     0.0
# 2015-01-01 22:00:00       0.000000    0.0     0.0
# 2015-01-01 23:00:00       0.000000    0.0     0.0
# 2015-01-02 00:00:00       0.000000    0.0     0.0
# 2015-01-02 01:00:00       0.000000    0.0     0.0
# 2015-01-02 02:00:00       0.000000    0.0     0.0
# 2015-01-02 03:00:00       0.000000    0.0     0.0
# 2015-01-02 04:00:00       0.000000    0.0     0.0
# 2015-01-02 05:00:00       0.000000    0.0     0.0
# 2015-01-02 06:00:00       0.000000    0.0     0.0
# 2015-01-02 07:00:00       0.000000    0.0     0.0
# 2015-01-02 08:00:00       0.000000    0.0     0.0
# 2015-01-02 09:00:00       0.000000    0.0     0.0
# 2015-01-02 10:00:00       0.000000    0.0     0.0
# 2015-01-02 11:00:00       0.000000    0.0     0.0
# 2015-01-02 12:00:00       0.000000    0.0     0.0
# 2015-01-02 13:00:00       0.000000    0.0     0.0
# 2015-01-02 14:00:00       0.000000    0.0     0.0
# 2015-01-02 15:00:00       0.000000    0.0     0.0
# 2015-01-02 16:00:00       0.000000    0.0     0.0
# 2015-01-02 17:00:00       0.000000    0.0     0.0
# 2015-01-02 18:00:00       0.000000    0.0     0.0
# 2015-01-02 19:00:00  159034.591620    0.0     0.0
# 2015-01-02 20:00:00  102628.285759    0.0     0.0
# 2015-01-02 21:00:00   74015.610882    0.0     0.0
# 2015-01-02 22:00:00       0.000000    0.0     0.0
# 2015-01-02 23:00:00       0.000000    0.0     0.0
