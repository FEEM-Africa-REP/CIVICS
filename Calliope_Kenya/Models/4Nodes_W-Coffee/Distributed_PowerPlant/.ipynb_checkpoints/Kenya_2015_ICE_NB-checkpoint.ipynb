# %%
import calliope
import Graphs as gg

# %%
try:
    calliope.set_log_level('INFO')
except:
    calliope.set_log_verbosity('INFO')
model = calliope.Model('model.yaml')
model.run()
# Out:
# [2020-05-13 18:57:18] INFO     Model: initialising
# [2020-05-13 18:57:18] WARNING  C:\Users\Amin\Anaconda3\envs\calliope\lib\site-packages\calliope\core\preprocess\model_run.py:227: FutureWarning:
#
# There will be no default cost class for the objective function in v0.7.0 (currently "monetary" with a weight of 1). Explicitly specify the cost class(es) you would like to use under `run.objective_options.cost_class`. E.g. `{"monetary": 1}` to replicate the current default.
#
#
# [2020-05-13 18:57:18] WARNING  Warning: Possible issues found during model processing:
#  * `monetary` interest rate of zero for technology supply_biomass, setting depreciation rate as 1/lifetime.
#
# [2020-05-13 18:57:19] INFO     `BiogasStorage` at `NBOR` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2020-05-13 18:57:19] INFO     Model: preprocessing stage 1 (model_run)
# ...

# %%
gg.Dispatch_sys(model,'bio_coffee_pp',pie_values='value')
gg.Dispatch_reg(model,sp_tech=False,sp_reg=False,weekly=False,pie_values='value')
# Out:
# [2020-05-13 18:58:43] WARNING  C:\Users\Amin\Documents\GitHub\My Kenya\Kenya Model\Graphs.py:579: MatplotlibDeprecationWarning:
#
# Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#
#
# 1
# [2020-05-13 18:58:45] WARNING  C:\Users\Amin\Documents\GitHub\My Kenya\Kenya Model\Graphs.py:323: MatplotlibDeprecationWarning:
#
# Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#
#
# 1
# [2020-05-13 18:58:46] WARNING  C:\Users\Amin\Documents\GitHub\My Kenya\Kenya Model\Graphs.py:323: MatplotlibDeprecationWarning:
#
# Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#
#
# 1
# [2020-05-13 18:58:47] WARNING  C:\Users\Amin\Documents\GitHub\My Kenya\Kenya Model\Graphs.py:323: MatplotlibDeprecationWarning:
#
# ...
